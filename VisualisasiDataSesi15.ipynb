# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

bulan = ['Januari','Februari','Maret','April','Mei','Juni','Juli','Agustus','September','Oktober','November','Desember']

#Pengeluaran antara 500.000 - 2.000.000

Minggu_1 = np.random.randint (500000,2000001,12)
Minggu_2 = np.random.randint (500000,2000001,12)
Minggu_3 = np.random.randint (500000,2000001,12)
Minggu_4 = np.random.randint (500000,2000001,12)

data = {
    'bulan' : bulan,
    'Minggu_1' : Minggu_1,
    'Minggu_2' : Minggu_2,
    'Minggu_3' : Minggu_3,
    'Minggu_4' : Minggu_4
}

df = pd.DataFrame(data)
df['Total_Pengeluaran'] = df[['Minggu_1', 'Minggu_2', 'Minggu_3', 'Minggu_4']].sum(axis=1)
df
# Out:
#         bulan  Minggu_1  Minggu_2  Minggu_3  Minggu_4  Total_Pengeluaran
# 0     Januari    997619   1488792   1440480   1422256            5349147
# 1    Februari    501764    959200   1257481   1691246            4409691
# 2       Maret   1280106    986852   1570030   1739020            5576008
# 3       April   1232989    673851   1440490    794757            4142087
# 4         Mei    574219    506926   1538444    807499            3427088
# 5        Juni   1354717   1937067   1300810   1662002            6254596
# 6        Juli   1686237   1525059    948193    910282            5069771
# 7     Agustus   1047822    920950    804837    659246            3432855
# 8   September   1490466   1070109   1568497   1883877            6012949
# 9     Oktober    705437    599539   1494678   1131826            3931480
# 10   November   1896964   1243511   1838443   1914232            6893150
# 11   Desember   1738674    618601    666612    526132            3550019

# %%
#Total Pengeluaaran Per Bulan

plt.figure (figsize=(12,6)) #Canvas dengan ukuran width,height (inch)
plt.title ('Total Pengeluaran Per Bulan')
plt.bar(df['bulan'],df['Total_Pengeluaran'],color='blue')
plt.xticks(rotation=45)
plt.ylabel("Rupiah")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#scatter plot untuk analisa data pengeluaran per minggu per bulan
plt.figure(figsize=(12,6))
for minggu in ['Minggu_1','Minggu_2','Minggu_3','Minggu_4']:
    plt.plot(df['bulan'],df[minggu], marker='o', label=minggu)

plt.title("Pengeluaran Per Minggu")
plt.xlabel('Bulan')
plt.ylabel("Pengeluaran (Rupiah)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Pie Chart -> Prosentase
plt.figure (figsize =(7,7))
plt.pie(df['Total_Pengeluaran'], labels=df['bulan'],startangle=90,autopct='%1.1f%%')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

df['bulan_angka'] = np.arange(1,13)

x = df[['bulan_angka']]
y = df['Total_Pengeluaran']

model = LinearRegression()

model.fit(x,y)

prediksi = model.predict([[13]]) [0]
print(f"Hasil Prediksi adalah :{prediksi:,.0f}")
# Out:
# Hasil Prediksi adalah :4,820,036
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('jumlah_hotel_dan_penginapan_di_kabupaten_sukabumi.csv')
df
# Out:
#     id  kode_provinsi nama_provinsi  bps_kode_kabupaten_kota  \
# 0    1             32    JAWA BARAT                     3202
# 1    2             32    JAWA BARAT                     3202
# 2    3             32    JAWA BARAT                     3202
# 3    4             32    JAWA BARAT                     3202
# 4    5             32    JAWA BARAT                     3202
# 5    6             32    JAWA BARAT                     3202
# 6    7             32    JAWA BARAT                     3202
# 7    8             32    JAWA BARAT                     3202
# 8    9             32    JAWA BARAT                     3202
# 9   10             32    JAWA BARAT                     3202
# 10  11             32    JAWA BARAT                     3202
# 11  12             32    JAWA BARAT                     3202
# 12  13             32    JAWA BARAT                     3202
# 13  14             32    JAWA BARAT                     3202
# ...

# %% [markdown]
# <p>Skenario Analisa Data</p>
# <ol>
# <li> Dari data tersebut saya dapat mencatat jumlah hotel dan penginapan di kabupaten sukabumi, jawa barat dari tahun 2021 hingga 2024. Data dikategorikan berdasarkan jenis akomodasi (hotel bintang 1 - 5 dan hotel melati/losmen/penginapan)</li>
# <li> Jumlah penginapan non-bintang yang sangat tinggi (140 unit) menunjukkan pasar akomodasi di sukabumi didominasi oleh segmen ekonomi.</li>
# <li> Tidak adanya hotel bintang 5 menunjukkan kabupaten sukabumi belum menjadi destinasi mewah atau bisnis skala tinggi.</li>
# <li> Data ini menunjukkan kabupaten sukabumi memiliki pasar akomodasi yang didominasi penginapan ekonomi dengan perkembangan positif di segmen menengah, tetapi belum menarik investasi di segmen mewah.</li>
